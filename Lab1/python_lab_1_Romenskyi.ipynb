# %% [markdown]
# ---
# title: "Лабораторна робота №1. Інсталяція та налаштування Python-середовища"
# description:
#   Документ зроблено за допомогою [Quarto](https://quarto.org/)
# author: "Роменський В'ячеслав, 2023"
# date: "09.10.2023"
# lang: ukr
# format:
#   html:
#     code-fold: true
#     toc: true # меню
#     toc_float: # спливаюче меню
#       collapsed: true # авто
#       number_sections: true
# jupyter: python3
# ---

# %% [markdown]
# __Мета:__ _quick start для роботи з python3 у середовищі IDE PyCharm системою контроля версій git._

# %% [markdown]
# ## Виконання завдань для самостійної роботи
#
# 1. Завантажити і встановити `Python`.
#     * Завантаження `Python` на `Ubuntu` за допомогою `apt`:
#     ![Install Python](Images/python_install.jpg)
#     * Перевірка роботи `Python`:
#     ![Python Ver](Images/python_ver.jpg)
# 1. Завантажити, встановити і налаштувати IDE PyCharm у відповідності з інструкціями, описаними вище
#     * Завантаження `PyCharm` із `Snap`:
#     ![Install PyCharm](Images/pycharm_install.jpg)
#     * Лого `PyCharm`:
#     ![PyCharm Logo](Images/pycharm_logo.jpg)
# 1. Завантажити, встановити і налаштувати систему контроля версій Git на вашому робочому комп'ютері.
#     * Завантаження `Git` за допомогою `apt`:
#     ![Install Git](Images/git_install.jpg)
# 1. Створити акаунт на GitHub та стоврити в ньому новий проєкт з іменем
# __StudentLastName_project__.
#     * Створення відкритого репозиторію [(посилання на нього)](https://github.com/FTSadori/Romenskyi_project):
#     ![Git Repo Creation](Images/github_create_repo.jpg)
# 1. Налаштувати зв'язок `PyCharm` з `Git`.
#     * Реєстрація на `Git` через `PyCharm`. Налаштування зв'язку із репозиторієм:
#     ![Open git 1](Images/pycharm_open_git.jpg)
# 1. Налаштувати зв'язок `PyCharm` з віддаленим репозиторієм на `GitHub`.
#     * Клоновані файли із репозиторія:
#     ![Open git 2](Images/pycharm_open_git2.jpg)
# 1. Створити файл __lab_1_StudentLastName.py__ з кодом, який виводить фразу __"Привіт, Ваше Прізвище"__.
#     * Додання файлу, що виводить необхідний рядок:
#     ![Open git 3](Images/pycharm_open_git3.jpg)
# 1. Закомітити файл у локальний репозиторій.
#     * Використання `Git` через термінал:
#     ![Git Commit](Images/git_commit.jpg)
# 1. Відправити ("запушити") поточну версію Git-проєкта у віддалений репозиторій на `GitHub`.
#     * Використання `Git` через термінал:
#     ![Git Push](Images/git_push.jpg)
# 1. Звіт має складатися з файлу (за основу взяти __цей Python-зошит__) з відповідними скріншотами `lab_1_StudentLastName.ipynb`. У звіті має бути посилання на Ваш GitHub-репозиторій з Вашим проєктом та відповіді на контролі запитання.
#     * [(Посилання на репозиторій)](https://github.com/FTSadori/Romenskyi_project)

# %% [markdown]
# ## Відповіді на контрольні запитання
#
# 1. У чому відмінність інтерпретатора від компілятора? Python -- компілятор чи інтерпретатор?
#     * Що інтерпретатор, що компілятор, є трансляторами, що перекладають мову високого рівня на машинний код. Але відмінність в тому, що компілятор перед виконанням програми перетворює файли в об'єктні, що далі об'єднаються у виконавчий файл, який виконується комп'ютером на максимальній швидкості. В той же час інтерпретатор кожен раз переводить файл рядок за рядком, переводячи його із мови високого рівня, на машинний код. Таким чином, інтерпретатор працює повільніше, але має варіант виконувати код у стилі "терміналу", вводячи рядки.
# 1. Що таке IDE PyCharm?
#     * IDE (integrated development environment - інтегроване середовище розробки) - це середовище, що містить велику кількість програм для спрощення процессу програмування. В той час PyCharm був розроблений для програмування на Python.
# 1. Що таке система контроля версій (СКВ) і для чого вона призначена? У чому принципова відмінність СКВ SVN та GIT?
#     * Система контроля версій вирішує питання контролю командної розробки, дозволяє зберігати зміни на віддаленому репозиторії та відкатувати їх, якщо буде необхідно. SVN є централізованою (всі дані зберігаються в одному місці), коли Git є розподіленою.
# 1. Що відбувається при виконанні команди `git add .`?
#     * Під час виконання данної команди ми додаємо всі дії із зміненими/новостворенними/видаленними файлами (що не містяться у .gitignore) для подальшого коміту.
# 1. Що відбувається при виконанні команди `git commit`?
#     * Данною командою ми зберігаємо зміни в нашому локальному репозиторії.
# 1. Якою Git-командою виконується розміщення локальної копії Git-репозиторію проєкта на віддаленому, що знаходиться на GitHub?
#     * Щоб відправити зміни, зроблені локально, до віддаленого репозиторія, необхідно виконати команду `git push -u origin master`

# %% [markdown]
# ## Висновок
#
# Під час лабораторної роботи було засвоєно навички по встановленню мови програмування python3, системи контролю версій Git, а також IDE PyCharm. Також було створено репозиторій на GitHub та вивчено базові команди по роботі із ним.
